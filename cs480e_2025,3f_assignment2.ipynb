# %% [markdown]
# <a href="https://colab.research.google.com/github/damnshah17/Damnshah/blob/main/cs480e_2025%2C3f_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2
# **Due November 16th, 11:59 PM**
#
# GitHub Classroom assignment link:
# https://classroom.github.com/a/DlsFesvO.
#
# Instructions for how to connect your Google Colab to GitHub are [here](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb).

# %% [markdown]
# Name: \<Daaman Shah\><br>
# B-Number: \<B01107800\><br>
# Email: \<dshah13@binghamton.edu\>

# %% [markdown]
# In the following assignment, you will be using the deep learning framework, PyTorch, to perform computer vision tasks such as image classification and object detection. This will be a report-style assignment, where you will try multiple different models, optimization algorithms, and hyperparameters, and present your findings in a short report with visualizations inside the notebook.
#
#
# Functions and cells that need to be implemented are marked with a bold **implement** keyword or clearly marked in the experiments section.
#
# The experiments section for each classifier also need to be implemented. You should follow the instructions above the cell. You may also add additional cells.
#
# Cells marked **run** need to be run to set up the appropriate infrastructure, but do not need to be modified. Make sure you have run the previous cells before running the current cell, or you may get an error.
#
# It is standard practice in ML to share notebooks to discuss the workflow and results in a professional setting. So, the code quality also matters. You should make sure your code is readable and conforms to standard practices. Your figures should be intelligable and include proper axis labels, titles, and legends. Unreadable and poorly written code may result in a points deduction.
#
# Submission will be via GitHub Classroom. **You are required to have at least 15 commits for this assignment.**

# %% [markdown]
# ## Uploading and Downloading Data from Colab
#
# Unlike the previous assignments, you will downloading and uploading additional data from and into the Colab environment.
#
# You can mount directories from your Google Drive and use the session storage for your work.
#
# [Take a look here for an example notebook on handling data download and upload on Colab. ](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=hauvGV4hV-Mh)

# %% [markdown]
# ## Import statements
#
# **Run** the cell to import the packages needed for the code below. You may other packages but ask first.

# %%
import torch
import csv
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# %%
torch.manual_seed(42)  # Set the seed for the random number generator

# %% [markdown]
# ## CUDA Runtime
#
# You will want to make use of the GPU runtimes on Colab to speed up your training. You can change your runtime by going to:
#
# `Runtime > Change runtime type` and selecting GPU.
#
# You will have to explicitly use the send Torch tensors to GPUs, by calling `.cuda()`  on the tensors and modules to utilize them on the GPU.
#
# [Take a look at the quickstart for PyTorch](https://pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html)

# %%
# CUDA Runtime Setup
# Check if CUDA (GPU) is available and set device accordingly
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# If CUDA is available, print GPU information
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
    print(f"CUDA Version: {torch.version.cuda}")
else:
    print("WARNING: CUDA is not available. Using CPU instead.")
    print("To enable GPU acceleration, go to: Runtime > Change runtime type > GPU")

# Set random seeds for reproducibility
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

print("\nTo change your runtime to GPU, go to: Runtime > Change runtime type and select GPU")
print("Make sure to call .cuda() on your tensors and models, or use .to(device) as shown below:")
print("Example: model = MyModel().to(device)")
print("Example: data = data.to(device)")
# Out:
# Using device: cuda
# GPU Name: Tesla T4
# GPU Memory: 14.7 GB
# CUDA Version: 12.6
#
# To change your runtime to GPU, go to: Runtime > Change runtime type and select GPU
# Make sure to call .cuda() on your tensors and models, or use .to(device) as shown below:
# Example: model = MyModel().to(device)
# Example: data = data.to(device)

# %% [markdown]
# ## Part 1: Data Handling in PyTorch (20 pts)

# %% [markdown]
# ### Dataset class
#
# A large part of any machine learning workflow is the proper and efficient handling of data. Datasets are often large, scattered across filesystems, and require transformations and augmentation. Deep learning libraries such as `PyTorch` provide utilities to help in this process. In the next section, you will write a custom MNIST dataset and add data augmentation to your data pipeline for your traininig.

# %% [markdown]
# **Run** the following cell to define some helper functions to load the MNIST data.

# %%
def _data_parser_helper(csv_file_name):
  '''
  Reads CSV file and converts it into numpy arrays.

  Args:
    csv_file_name (string): String of the path of csv file.

  Returns:
    (np.array(float), np.array(int)): Returns a tuple of numpy arrays.
  '''
  X = []
  Y = []
  with open(csv_file_name,'r') as _file:
      csv_reader = csv.reader(_file, delimiter=",")
      for row in csv_reader:
          Y.append(int(row[0]))
          X.append([float(i)/255.0 for i in row[1:]])
  return (np.array(X), np.array(Y))

def get_mnist_train_data():
  X_train, Y_train = _data_parser_helper("sample_data/mnist_train_small.csv")
  return X_train, Y_train

def get_mnist_test_data():
  X_test, Y_test = _data_parser_helper("sample_data/mnist_test.csv")
  return X_test, Y_test

# %% [markdown]
# ***Implement*** the `MNIST` class to serve as a container for our PyTorch MNIST data. [Take a look at this tutorial on PyTorch datasets, dataloading, and transforms.](https://pytorch.org/tutorials/beginner/data_loading_tutorial.html#dataset-class)
# [This second, more important tutorial specifically covers custom datasets and dataloaders.](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files)
#
# The MNIST data on Colab is pre-installed on all notebooks as a CSV.
# Your class must read the data and store it as PyTorch float tensors.
# Use the helper functions above (already written) to read the data,
# which will return the data as NumPy arrays.
#
# You should implement:
#
# - `__init__()` to read the appropriate CSV file, and store it in the class as a `torch.Tensor` with float dtype.
# - `__len__()` to return the number of samples in the dataset.
# - `__getitem__(i)` to return the i-th sample and label from the data you have stored.

# %%
class MNIST(Dataset):
  """MNIST custom dataset that reads the CSV file and transforms them into PyTorch Tensors"""


  def __init__(self, is_training=True, transform=None):
    """
    Args:
      is_training (bool): If true loads
        the training dataset. If false, loads the test dataset.
        Use the functions above.
      transform (callable): Transform to be applied on a sample.
        These will be used for data augmentations.
    """
    super().__init__()

    if is_training:
        self._data, self._label = get_mnist_train_data()
        self._data = torch.from_numpy(self._data.reshape((20000, 1, 28, 28))).float()
    else:
        self._data, self._label = get_mnist_test_data()
        self._data = torch.from_numpy(self._data.reshape((10000, 1, 28, 28))).float()

    self._label = torch.from_numpy(self._label)
    self.transform = transform


  def __len__(self):
    """Returns the size (the number of samples) of the dataset.
    """

    # raise NotImplementedError("The __len__() method was not implemented.")
    return self._data.shape[0]

  def __getitem__(self, i):
    """Returns the i-th sample and label and applies any transforms defined.

      Args:
        i (int): The index of sample in the data array to retrieve.
    """

    # return NotImplementedError("The __getitem__() method was not implemented")

    sample = self._data[i]
    label = self._label[i]
    if (self.transform):
      sample = self.transform(sample)
    return sample, label

# %%
composed = transforms.Compose([transforms.RandomRotation(15)])
mnist_dataset = MNIST(transform=composed)

# %%
from time import perf_counter

# %%
loader = DataLoader(mnist_dataset, batch_size=512, num_workers=2)

# %%
start = perf_counter()
for _data, label in loader:
  x = _data.shape[0]
end = perf_counter()

# %%
print(end-start)
# Out:
# 5.6844704809999484

# %% [markdown]
# ***Implement*** the following cell to visualize the data in the dataset. Use `Matplotlib` or your favorite visualization package to plot 5 images of each class in a single figure.
#
# You should initialize a MNIST dataset object for the training class. Visualize this dataset. This will not be used in the future.

# %% [markdown]
# ***Implement***
# the following cell to create a PyTorch transform object and
# assign it to a variable.
# You may name the variable whatever you wish;
# you will use the object to construct train and test MNIST datasets.
#
# You will use the transformations defined in `torchvision`,
# which can be found [here](https://pytorch.org/vision/stable/transforms.html#transforms-on-pil-image-and-torch-tensor).
#
# Add the `RandomRotation` and `Normalize` transformations to the dataset. You will need to [compose the two transforms](https://pytorch.org/vision/0.9/transforms.html#torchvision.transforms.Compose). Restrict the rotations to +/- 15 degrees.
#
# The mean and standard deviation of the training set is 0.13 and 0.31 respectively.
#
# At the end of the cell, construct a training and test dataset.
# Name these carefully, these datasets will be used in the next sections.

# %%
transform  = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(degrees = (15)),
    transforms.Normalize((0.1307,), (0.3081,))
    ])

mnist_train = MNIST(is_training=True, transform=transform)
mnist_test = MNIST(is_training=False, transform=transform)

# %% [markdown]
# ***Implement*** the following cell to visualize the data in the dataset with the transformations similar to the previous visualization.

# %% [markdown]
# ***Implement*** the following cell to randomly split the training dataset previously defined, and make a training and validation set. Do an 80-20 split for the training and validation set. Name these sets carefully, they will be used in the next section to train your models.
#
# You can use the utilities in `torch.utils.data`.

# %%
from torch.utils.data import random_split
train_len = int(0.8 * len(mnist_train))
val_len = len(mnist_train) - train_len
train_set, val_set = random_split(mnist_train, [train_len, val_len])

# %% [markdown]
# ## Part 2: MNIST Classification (40 pts)

# %% [markdown]
# ### Linear Classifiers
#
# The linear classifiers you implemented in the last assignment will serve as our baseline for more powerful convolutional neural networks. You will ***implement*** the multi-class SVM and  Softmax classifiers in the following cells.

# %% [markdown]
# **Implement** a LinearSVM classifier in the following cell. Your implementation should be a python class that inherits from `torch.nn.Module`.
#
# You should use classes and functions defined in `torch.nn` and `torch.nn.Functional`.

# %%
class LinearSVM(nn.Module):
  ''' Implements the linear SVM using Torch.
  '''
  def __init__(self, num_classes, *args, **kwargs):
    '''
      num_classes (int): The number of output classes
    '''
    raise NotImplementedError("LinearSVM forward not implemented")

  def forward(self, x):
    '''
      x (torch.Tensor): Input image as a torch tensor.
    '''
    raise NotImplementedError("LinearSVM forward not implemented")

# %% [markdown]
# ***Implement*** using any PyTorch defined optimizer, code to train your LinearSVM classifier on the training dataset. You will want to try different optimizers, learning rates, and batch sizes.
#
# PyTorch provides implementations of various optimization algorithms in the `torch.optim` package. You can use any of the first order methods such as:
#
# - SGD (with or without momentum)
# - AdaDelta
# - ADAM
# - RProp
# - RMSProp
#
# ***Note:*** You should keep track of the performance of the optimizers, batch sizes, and learning rates. You should justify the choice of your hyperparameters in the report at the end of this section. You will be asked to quantify and visualize the differences between these hyperparameters.
#
# You should use `Torch.utils.data.DataLoader` to do the data loading. Make sure to use the correct loss function. You may use the predefined loss functions available in `Torch.nn`.
#
# ***Note:*** As the optimization procedure for training different models is often the same, you should write helper functions that are reusable. This will make your code more readable and reduce the possibility of unexpected bugs.
#
# To train a single model, you will need to:
#
# - Iterate through the data in batches using your training or validation dataloader
# - Perform the forward pass
# - Compute the loss
# - Perform the backward pass
# - Take an optimizer step
# - Repeat the process till network converges or some other criterion
# - Every n iterations, go through the validation set and calculate the loss and accuracy of the validation set to check your training performance

# %%
# Out:
# Using device: cuda
#
# === Training LinearSVM: batch_size=32, lr=0.001, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 1.1969, Train Acc: 79.31% | Val Loss: 0.7399, Val Acc: 85.35%
# Epoch [2/10] - Train Loss: 0.6885, Train Acc: 86.49% | Val Loss: 0.6439, Val Acc: 86.75%
# Epoch [3/10] - Train Loss: 0.6243, Train Acc: 87.17% | Val Loss: 0.6047, Val Acc: 87.35%
# Epoch [4/10] - Train Loss: 0.6042, Train Acc: 87.29% | Val Loss: 0.5844, Val Acc: 88.20%
# Epoch [5/10] - Train Loss: 0.5719, Train Acc: 88.26% | Val Loss: 0.5686, Val Acc: 87.95%
# Epoch [6/10] - Train Loss: 0.5672, Train Acc: 88.26% | Val Loss: 0.5749, Val Acc: 87.60%
# Epoch [7/10] - Train Loss: 0.5493, Train Acc: 88.35% | Val Loss: 0.5441, Val Acc: 88.42%
# Epoch [8/10] - Train Loss: 0.5460, Train Acc: 88.70% | Val Loss: 0.5444, Val Acc: 88.25%
# Epoch [9/10] - Train Loss: 0.5297, Train Acc: 89.00% | Val Loss: 0.5441, Val Acc: 88.62%
# Epoch [10/10] - Train Loss: 0.5196, Train Acc: 88.97% | Val Loss: 0.5371, Val Acc: 88.47%
#
# === Training LinearSVM: batch_size=32, lr=0.001, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 0.8829, Train Acc: 83.60% | Val Loss: 0.6551, Val Acc: 87.10%
# Epoch [2/10] - Train Loss: 0.6215, Train Acc: 86.81% | Val Loss: 0.6417, Val Acc: 85.97%
# Epoch [3/10] - Train Loss: 0.5957, Train Acc: 87.71% | Val Loss: 0.5687, Val Acc: 88.15%
# Epoch [4/10] - Train Loss: 0.5847, Train Acc: 87.79% | Val Loss: 0.5471, Val Acc: 88.65%
# Epoch [5/10] - Train Loss: 0.5511, Train Acc: 88.17% | Val Loss: 0.6083, Val Acc: 87.58%
# Epoch [6/10] - Train Loss: 0.5543, Train Acc: 88.39% | Val Loss: 0.5751, Val Acc: 88.35%
# Epoch [7/10] - Train Loss: 0.5458, Train Acc: 88.26% | Val Loss: 0.5627, Val Acc: 87.97%
# Epoch [8/10] - Train Loss: 0.5424, Train Acc: 88.49% | Val Loss: 0.5637, Val Acc: 88.28%
# Epoch [9/10] - Train Loss: 0.5451, Train Acc: 88.49% | Val Loss: 0.5492, Val Acc: 88.22%
# Epoch [10/10] - Train Loss: 0.5451, Train Acc: 88.43% | Val Loss: 0.5815, Val Acc: 87.53%
#
# === Training LinearSVM: batch_size=32, lr=0.001, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 0.9932, Train Acc: 82.14% | Val Loss: 0.6370, Val Acc: 86.30%
# Epoch [2/10] - Train Loss: 0.5978, Train Acc: 87.56% | Val Loss: 0.5797, Val Acc: 87.47%
# Epoch [3/10] - Train Loss: 0.5727, Train Acc: 87.79% | Val Loss: 0.5513, Val Acc: 88.28%
# Epoch [4/10] - Train Loss: 0.5719, Train Acc: 88.03% | Val Loss: 0.5750, Val Acc: 87.20%
# Epoch [5/10] - Train Loss: 0.5531, Train Acc: 88.41% | Val Loss: 0.5618, Val Acc: 88.05%
# Epoch [6/10] - Train Loss: 0.5591, Train Acc: 88.16% | Val Loss: 0.5652, Val Acc: 87.72%
# Epoch [7/10] - Train Loss: 0.5510, Train Acc: 88.12% | Val Loss: 0.5656, Val Acc: 87.88%
# Epoch [8/10] - Train Loss: 0.5491, Train Acc: 88.28% | Val Loss: 0.5642, Val Acc: 87.83%
# Epoch [9/10] - Train Loss: 0.5478, Train Acc: 88.40% | Val Loss: 0.5891, Val Acc: 87.15%
# Epoch [10/10] - Train Loss: 0.5465, Train Acc: 88.58% | Val Loss: 0.5680, Val Acc: 88.20%
#
# === Training LinearSVM: batch_size=32, lr=0.001, optimizer=RMSprop ===
# Epoch [1/10] - Train Loss: 0.8768, Train Acc: 83.16% | Val Loss: 0.5720, Val Acc: 87.05%
# Epoch [2/10] - Train Loss: 0.6151, Train Acc: 87.00% | Val Loss: 0.6121, Val Acc: 86.97%
# Epoch [3/10] - Train Loss: 0.5882, Train Acc: 87.39% | Val Loss: 0.5494, Val Acc: 88.05%
# Epoch [4/10] - Train Loss: 0.5860, Train Acc: 87.70% | Val Loss: 0.6334, Val Acc: 86.33%
# Epoch [5/10] - Train Loss: 0.5708, Train Acc: 87.79% | Val Loss: 0.5371, Val Acc: 88.35%
# Epoch [6/10] - Train Loss: 0.5665, Train Acc: 88.19% | Val Loss: 0.5734, Val Acc: 87.95%
# Epoch [7/10] - Train Loss: 0.5785, Train Acc: 88.03% | Val Loss: 0.5712, Val Acc: 88.25%
# Epoch [8/10] - Train Loss: 0.5597, Train Acc: 88.11% | Val Loss: 0.6814, Val Acc: 86.38%
# Epoch [9/10] - Train Loss: 0.5536, Train Acc: 88.58% | Val Loss: 0.5933, Val Acc: 88.22%
# Epoch [10/10] - Train Loss: 0.5574, Train Acc: 88.44% | Val Loss: 0.5865, Val Acc: 87.88%
#
# === Training LinearSVM: batch_size=32, lr=0.01, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 0.8486, Train Acc: 83.24% | Val Loss: 0.6585, Val Acc: 86.08%
# Epoch [2/10] - Train Loss: 0.6389, Train Acc: 86.91% | Val Loss: 0.6039, Val Acc: 87.78%
# Epoch [3/10] - Train Loss: 0.6075, Train Acc: 87.11% | Val Loss: 0.5811, Val Acc: 87.75%
# Epoch [4/10] - Train Loss: 0.5770, Train Acc: 87.81% | Val Loss: 0.6088, Val Acc: 86.55%
# Epoch [5/10] - Train Loss: 0.5703, Train Acc: 88.08% | Val Loss: 0.6291, Val Acc: 86.55%
# Epoch [6/10] - Train Loss: 0.5552, Train Acc: 88.31% | Val Loss: 0.5718, Val Acc: 88.62%
# Epoch [7/10] - Train Loss: 0.5627, Train Acc: 88.17% | Val Loss: 0.5608, Val Acc: 88.28%
# Epoch [8/10] - Train Loss: 0.5503, Train Acc: 88.39% | Val Loss: 0.5615, Val Acc: 88.12%
# Epoch [9/10] - Train Loss: 0.5436, Train Acc: 88.45% | Val Loss: 0.5798, Val Acc: 88.10%
# Epoch [10/10] - Train Loss: 0.5372, Train Acc: 88.39% | Val Loss: 0.6121, Val Acc: 87.00%
#
# === Training LinearSVM: batch_size=32, lr=0.01, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 2.0730, Train Acc: 80.96% | Val Loss: 1.5002, Val Acc: 84.12%
# Epoch [2/10] - Train Loss: 1.5361, Train Acc: 84.14% | Val Loss: 1.6140, Val Acc: 83.72%
# Epoch [3/10] - Train Loss: 1.5776, Train Acc: 84.03% | Val Loss: 1.5182, Val Acc: 85.50%
# Epoch [4/10] - Train Loss: 1.4834, Train Acc: 84.58% | Val Loss: 1.3281, Val Acc: 85.60%
# Epoch [5/10] - Train Loss: 1.4139, Train Acc: 84.41% | Val Loss: 1.4918, Val Acc: 85.88%
# Epoch [6/10] - Train Loss: 1.4346, Train Acc: 84.89% | Val Loss: 1.3800, Val Acc: 86.03%
# Epoch [7/10] - Train Loss: 1.3928, Train Acc: 85.16% | Val Loss: 1.4186, Val Acc: 85.75%
# Epoch [8/10] - Train Loss: 1.4549, Train Acc: 84.57% | Val Loss: 1.6993, Val Acc: 82.80%
# Epoch [9/10] - Train Loss: 1.4478, Train Acc: 84.53% | Val Loss: 1.5156, Val Acc: 85.35%
# Epoch [10/10] - Train Loss: 1.3767, Train Acc: 85.12% | Val Loss: 1.5248, Val Acc: 83.80%
#
# === Training LinearSVM: batch_size=32, lr=0.01, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 1.6431, Train Acc: 80.09% | Val Loss: 1.3657, Val Acc: 83.90%
# Epoch [2/10] - Train Loss: 1.5844, Train Acc: 83.11% | Val Loss: 1.3959, Val Acc: 85.47%
# Epoch [3/10] - Train Loss: 1.5911, Train Acc: 83.97% | Val Loss: 1.6790, Val Acc: 82.95%
# Epoch [4/10] - Train Loss: 1.6976, Train Acc: 83.86% | Val Loss: 1.7012, Val Acc: 85.22%
# Epoch [5/10] - Train Loss: 1.7134, Train Acc: 84.60% | Val Loss: 2.0971, Val Acc: 81.08%
# Epoch [6/10] - Train Loss: 1.7161, Train Acc: 84.52% | Val Loss: 1.7776, Val Acc: 84.10%
# Epoch [7/10] - Train Loss: 1.6776, Train Acc: 84.79% | Val Loss: 1.9019, Val Acc: 84.15%
# Epoch [8/10] - Train Loss: 1.7390, Train Acc: 84.54% | Val Loss: 2.3616, Val Acc: 80.53%
# Epoch [9/10] - Train Loss: 1.7494, Train Acc: 84.81% | Val Loss: 2.1330, Val Acc: 84.67%
# Epoch [10/10] - Train Loss: 1.9069, Train Acc: 84.33% | Val Loss: 1.8180, Val Acc: 84.83%
#
# === Training LinearSVM: batch_size=32, lr=0.01, optimizer=RMSprop ===
# Epoch [1/10] - Train Loss: 2.5807, Train Acc: 79.96% | Val Loss: 1.9025, Val Acc: 83.40%
# Epoch [2/10] - Train Loss: 1.9728, Train Acc: 83.00% | Val Loss: 1.9546, Val Acc: 83.42%
# Epoch [3/10] - Train Loss: 1.9635, Train Acc: 83.52% | Val Loss: 1.9111, Val Acc: 85.45%
# Epoch [4/10] - Train Loss: 1.9623, Train Acc: 83.99% | Val Loss: 1.7775, Val Acc: 86.78%
# Epoch [5/10] - Train Loss: 1.9341, Train Acc: 84.36% | Val Loss: 2.0785, Val Acc: 84.72%
# Epoch [6/10] - Train Loss: 1.9868, Train Acc: 84.74% | Val Loss: 1.8075, Val Acc: 87.33%
# Epoch [7/10] - Train Loss: 1.9863, Train Acc: 84.63% | Val Loss: 1.9051, Val Acc: 85.47%
# Epoch [8/10] - Train Loss: 1.9583, Train Acc: 84.96% | Val Loss: 2.0401, Val Acc: 86.28%
# Epoch [9/10] - Train Loss: 2.0060, Train Acc: 84.99% | Val Loss: 2.0736, Val Acc: 85.03%
# Epoch [10/10] - Train Loss: 2.0277, Train Acc: 84.38% | Val Loss: 2.0524, Val Acc: 86.58%
#
# === Training LinearSVM: batch_size=32, lr=0.1, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 2.2426, Train Acc: 79.85% | Val Loss: 1.7669, Val Acc: 83.30%
# Epoch [2/10] - Train Loss: 1.7337, Train Acc: 83.03% | Val Loss: 1.7109, Val Acc: 83.22%
# Epoch [3/10] - Train Loss: 1.6541, Train Acc: 83.80% | Val Loss: 1.7908, Val Acc: 80.40%
# Epoch [4/10] - Train Loss: 1.5831, Train Acc: 84.31% | Val Loss: 1.8044, Val Acc: 81.30%
# Epoch [5/10] - Train Loss: 1.5808, Train Acc: 84.24% | Val Loss: 1.6652, Val Acc: 83.62%
# Epoch [6/10] - Train Loss: 1.5006, Train Acc: 84.58% | Val Loss: 1.8117, Val Acc: 82.42%
# Epoch [7/10] - Train Loss: 1.5494, Train Acc: 84.81% | Val Loss: 1.5400, Val Acc: 83.38%
# Epoch [8/10] - Train Loss: 1.5269, Train Acc: 84.69% | Val Loss: 1.6003, Val Acc: 84.88%
# Epoch [9/10] - Train Loss: 1.4610, Train Acc: 85.03% | Val Loss: 1.6279, Val Acc: 85.00%
# Epoch [10/10] - Train Loss: 1.5003, Train Acc: 84.97% | Val Loss: 1.5357, Val Acc: 85.35%
#
# === Training LinearSVM: batch_size=32, lr=0.1, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 15.1586, Train Acc: 79.79% | Val Loss: 10.4079, Val Acc: 82.38%
# Epoch [2/10] - Train Loss: 12.2744, Train Acc: 81.54% | Val Loss: 13.7473, Val Acc: 81.03%
# Epoch [3/10] - Train Loss: 11.8255, Train Acc: 82.69% | Val Loss: 13.3045, Val Acc: 79.88%
# Epoch [4/10] - Train Loss: 10.8604, Train Acc: 83.26% | Val Loss: 11.6236, Val Acc: 84.05%
# Epoch [5/10] - Train Loss: 10.6118, Train Acc: 83.72% | Val Loss: 10.2931, Val Acc: 84.25%
# Epoch [6/10] - Train Loss: 10.7280, Train Acc: 83.53% | Val Loss: 11.7237, Val Acc: 83.45%
# Epoch [7/10] - Train Loss: 10.1575, Train Acc: 83.88% | Val Loss: 11.1524, Val Acc: 83.67%
# Epoch [8/10] - Train Loss: 10.3081, Train Acc: 83.56% | Val Loss: 12.5036, Val Acc: 82.83%
# Epoch [9/10] - Train Loss: 9.8630, Train Acc: 83.78% | Val Loss: 9.4393, Val Acc: 84.72%
# Epoch [10/10] - Train Loss: 10.1232, Train Acc: 83.84% | Val Loss: 12.0649, Val Acc: 83.55%
#
# === Training LinearSVM: batch_size=32, lr=0.1, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 11.6714, Train Acc: 78.33% | Val Loss: 9.9392, Val Acc: 83.45%
# Epoch [2/10] - Train Loss: 12.5266, Train Acc: 81.58% | Val Loss: 10.7744, Val Acc: 84.80%
# Epoch [3/10] - Train Loss: 13.3363, Train Acc: 82.39% | Val Loss: 13.2691, Val Acc: 83.03%
# Epoch [4/10] - Train Loss: 14.3545, Train Acc: 82.53% | Val Loss: 18.1894, Val Acc: 79.00%
# Epoch [5/10] - Train Loss: 14.8059, Train Acc: 83.22% | Val Loss: 13.8853, Val Acc: 85.15%
# Epoch [6/10] - Train Loss: 13.7806, Train Acc: 83.76% | Val Loss: 14.5105, Val Acc: 83.70%
# Epoch [7/10] - Train Loss: 15.3266, Train Acc: 83.34% | Val Loss: 20.6459, Val Acc: 79.10%
# Epoch [8/10] - Train Loss: 15.0776, Train Acc: 83.73% | Val Loss: 19.8427, Val Acc: 79.50%
# Epoch [9/10] - Train Loss: 14.2272, Train Acc: 83.78% | Val Loss: 14.4744, Val Acc: 85.30%
# Epoch [10/10] - Train Loss: 15.4158, Train Acc: 83.99% | Val Loss: 15.6807, Val Acc: 85.05%
#
# === Training LinearSVM: batch_size=32, lr=0.1, optimizer=RMSprop ===
# Epoch [1/10] - Train Loss: 21.4463, Train Acc: 78.49% | Val Loss: 18.2084, Val Acc: 81.03%
# Epoch [2/10] - Train Loss: 17.0040, Train Acc: 81.64% | Val Loss: 17.2502, Val Acc: 81.03%
# Epoch [3/10] - Train Loss: 16.9099, Train Acc: 82.66% | Val Loss: 15.3271, Val Acc: 84.30%
# Epoch [4/10] - Train Loss: 16.4329, Train Acc: 82.79% | Val Loss: 18.4307, Val Acc: 83.17%
# Epoch [5/10] - Train Loss: 16.9156, Train Acc: 83.42% | Val Loss: 20.5480, Val Acc: 81.20%
# Epoch [6/10] - Train Loss: 17.2465, Train Acc: 83.26% | Val Loss: 21.4930, Val Acc: 80.00%
# Epoch [7/10] - Train Loss: 16.3842, Train Acc: 84.01% | Val Loss: 22.0479, Val Acc: 80.12%
# Epoch [8/10] - Train Loss: 16.9869, Train Acc: 84.18% | Val Loss: 18.2521, Val Acc: 82.53%
# Epoch [9/10] - Train Loss: 17.4675, Train Acc: 83.63% | Val Loss: 17.1106, Val Acc: 83.85%
# Epoch [10/10] - Train Loss: 16.6309, Train Acc: 84.29% | Val Loss: 16.9614, Val Acc: 82.90%
#
# === Training LinearSVM: batch_size=64, lr=0.001, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 1.5129, Train Acc: 76.11% | Val Loss: 0.8775, Val Acc: 84.45%
# Epoch [2/10] - Train Loss: 0.7903, Train Acc: 85.07% | Val Loss: 0.7391, Val Acc: 86.08%
# Epoch [3/10] - Train Loss: 0.7172, Train Acc: 86.16% | Val Loss: 0.6821, Val Acc: 86.78%
# Epoch [4/10] - Train Loss: 0.6610, Train Acc: 86.87% | Val Loss: 0.6522, Val Acc: 86.97%
# Epoch [5/10] - Train Loss: 0.6303, Train Acc: 87.61% | Val Loss: 0.6206, Val Acc: 86.67%
# Epoch [6/10] - Train Loss: 0.6123, Train Acc: 87.73% | Val Loss: 0.5994, Val Acc: 87.78%
# Epoch [7/10] - Train Loss: 0.5978, Train Acc: 87.92% | Val Loss: 0.6101, Val Acc: 87.65%
# Epoch [8/10] - Train Loss: 0.5835, Train Acc: 88.26% | Val Loss: 0.5901, Val Acc: 87.95%
# Epoch [9/10] - Train Loss: 0.5764, Train Acc: 88.26% | Val Loss: 0.5745, Val Acc: 88.20%
# Epoch [10/10] - Train Loss: 0.5624, Train Acc: 88.48% | Val Loss: 0.5422, Val Acc: 88.35%
#
# === Training LinearSVM: batch_size=64, lr=0.001, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 0.8949, Train Acc: 83.03% | Val Loss: 0.5964, Val Acc: 87.12%
# Epoch [2/10] - Train Loss: 0.6030, Train Acc: 87.31% | Val Loss: 0.5417, Val Acc: 88.30%
# Epoch [3/10] - Train Loss: 0.5661, Train Acc: 87.88% | Val Loss: 0.5489, Val Acc: 88.05%
# Epoch [4/10] - Train Loss: 0.5480, Train Acc: 88.41% | Val Loss: 0.5492, Val Acc: 88.28%
# Epoch [5/10] - Train Loss: 0.5440, Train Acc: 88.50% | Val Loss: 0.5205, Val Acc: 87.60%
# Epoch [6/10] - Train Loss: 0.5179, Train Acc: 88.63% | Val Loss: 0.5486, Val Acc: 88.22%
# Epoch [7/10] - Train Loss: 0.5029, Train Acc: 89.01% | Val Loss: 0.5202, Val Acc: 88.42%
# Epoch [8/10] - Train Loss: 0.5171, Train Acc: 88.80% | Val Loss: 0.5292, Val Acc: 88.55%
# Epoch [9/10] - Train Loss: 0.5204, Train Acc: 88.81% | Val Loss: 0.5408, Val Acc: 88.17%
# Epoch [10/10] - Train Loss: 0.5132, Train Acc: 88.99% | Val Loss: 0.5257, Val Acc: 88.65%
#
# === Training LinearSVM: batch_size=64, lr=0.001, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 1.1311, Train Acc: 79.96% | Val Loss: 0.6395, Val Acc: 86.72%
# Epoch [2/10] - Train Loss: 0.6154, Train Acc: 87.33% | Val Loss: 0.5642, Val Acc: 87.33%
# Epoch [3/10] - Train Loss: 0.5668, Train Acc: 87.79% | Val Loss: 0.5447, Val Acc: 88.25%
# Epoch [4/10] - Train Loss: 0.5408, Train Acc: 88.76% | Val Loss: 0.5448, Val Acc: 88.62%
# Epoch [5/10] - Train Loss: 0.5327, Train Acc: 88.73% | Val Loss: 0.4811, Val Acc: 89.42%
# Epoch [6/10] - Train Loss: 0.5320, Train Acc: 88.39% | Val Loss: 0.5395, Val Acc: 88.42%
# Epoch [7/10] - Train Loss: 0.5278, Train Acc: 88.75% | Val Loss: 0.5082, Val Acc: 88.75%
# Epoch [8/10] - Train Loss: 0.5090, Train Acc: 88.82% | Val Loss: 0.5586, Val Acc: 87.28%
# Epoch [9/10] - Train Loss: 0.5080, Train Acc: 89.16% | Val Loss: 0.5360, Val Acc: 88.30%
# Epoch [10/10] - Train Loss: 0.5103, Train Acc: 88.84% | Val Loss: 0.5375, Val Acc: 88.45%
#
# === Training LinearSVM: batch_size=64, lr=0.001, optimizer=RMSprop ===
# Epoch [1/10] - Train Loss: 0.9152, Train Acc: 83.08% | Val Loss: 0.6150, Val Acc: 86.67%
# Epoch [2/10] - Train Loss: 0.6057, Train Acc: 87.11% | Val Loss: 0.5665, Val Acc: 88.03%
# Epoch [3/10] - Train Loss: 0.5761, Train Acc: 87.66% | Val Loss: 0.5928, Val Acc: 87.33%
# Epoch [4/10] - Train Loss: 0.5667, Train Acc: 88.12% | Val Loss: 0.5539, Val Acc: 87.90%
# Epoch [5/10] - Train Loss: 0.5507, Train Acc: 88.24% | Val Loss: 0.5502, Val Acc: 88.62%
# Epoch [6/10] - Train Loss: 0.5333, Train Acc: 88.47% | Val Loss: 0.5558, Val Acc: 87.70%
# Epoch [7/10] - Train Loss: 0.5335, Train Acc: 88.64% | Val Loss: 0.6263, Val Acc: 86.72%
# Epoch [8/10] - Train Loss: 0.5335, Train Acc: 88.71% | Val Loss: 0.5286, Val Acc: 88.60%
# Epoch [9/10] - Train Loss: 0.5248, Train Acc: 88.99% | Val Loss: 0.5666, Val Acc: 87.90%
# Epoch [10/10] - Train Loss: 0.5196, Train Acc: 88.60% | Val Loss: 0.5267, Val Acc: 89.08%
#
# === Training LinearSVM: batch_size=64, lr=0.01, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 0.8661, Train Acc: 83.42% | Val Loss: 0.6442, Val Acc: 87.08%
# Epoch [2/10] - Train Loss: 0.6104, Train Acc: 87.33% | Val Loss: 0.5916, Val Acc: 87.15%
# Epoch [3/10] - Train Loss: 0.5752, Train Acc: 87.86% | Val Loss: 0.5758, Val Acc: 87.60%
# Epoch [4/10] - Train Loss: 0.5569, Train Acc: 88.17% | Val Loss: 0.5684, Val Acc: 87.25%
# Epoch [5/10] - Train Loss: 0.5328, Train Acc: 88.57% | Val Loss: 0.5824, Val Acc: 87.67%
# Epoch [6/10] - Train Loss: 0.5341, Train Acc: 88.59% | Val Loss: 0.6018, Val Acc: 86.85%
# Epoch [7/10] - Train Loss: 0.5183, Train Acc: 88.72% | Val Loss: 0.5136, Val Acc: 88.30%
# Epoch [8/10] - Train Loss: 0.5229, Train Acc: 88.60% | Val Loss: 0.5317, Val Acc: 88.67%
# Epoch [9/10] - Train Loss: 0.5223, Train Acc: 88.78% | Val Loss: 0.5068, Val Acc: 88.97%
# Epoch [10/10] - Train Loss: 0.5166, Train Acc: 89.04% | Val Loss: 0.5350, Val Acc: 88.40%
#
# === Training LinearSVM: batch_size=64, lr=0.01, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 1.4214, Train Acc: 82.29% | Val Loss: 1.0941, Val Acc: 85.22%
# Epoch [2/10] - Train Loss: 1.0505, Train Acc: 84.81% | Val Loss: 1.0104, Val Acc: 85.38%
# Epoch [3/10] - Train Loss: 0.9775, Train Acc: 85.16% | Val Loss: 0.8777, Val Acc: 86.97%
# Epoch [4/10] - Train Loss: 0.9710, Train Acc: 85.55% | Val Loss: 1.0857, Val Acc: 83.50%
# Epoch [5/10] - Train Loss: 0.9538, Train Acc: 85.51% | Val Loss: 1.0932, Val Acc: 83.08%
# Epoch [6/10] - Train Loss: 0.9468, Train Acc: 85.88% | Val Loss: 1.0925, Val Acc: 84.58%
# Epoch [7/10] - Train Loss: 0.9199, Train Acc: 85.65% | Val Loss: 0.8781, Val Acc: 87.10%
# Epoch [8/10] - Train Loss: 0.9249, Train Acc: 85.78% | Val Loss: 1.1384, Val Acc: 83.53%
# Epoch [9/10] - Train Loss: 0.9084, Train Acc: 85.87% | Val Loss: 0.9929, Val Acc: 84.83%
# Epoch [10/10] - Train Loss: 0.9128, Train Acc: 86.29% | Val Loss: 0.9589, Val Acc: 85.40%
#
# === Training LinearSVM: batch_size=64, lr=0.01, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 1.3232, Train Acc: 81.06% | Val Loss: 1.4389, Val Acc: 80.05%
# Epoch [2/10] - Train Loss: 1.2133, Train Acc: 83.65% | Val Loss: 1.0965, Val Acc: 84.47%
# Epoch [3/10] - Train Loss: 1.1665, Train Acc: 84.31% | Val Loss: 1.4392, Val Acc: 84.17%
# Epoch [4/10] - Train Loss: 1.2270, Train Acc: 84.67% | Val Loss: 1.2479, Val Acc: 85.45%
# Epoch [5/10] - Train Loss: 1.2120, Train Acc: 84.86% | Val Loss: 1.2634, Val Acc: 84.92%
# Epoch [6/10] - Train Loss: 1.2996, Train Acc: 84.66% | Val Loss: 1.3939, Val Acc: 85.53%
# Epoch [7/10] - Train Loss: 1.3133, Train Acc: 84.89% | Val Loss: 1.4864, Val Acc: 82.28%
# Epoch [8/10] - Train Loss: 1.2508, Train Acc: 85.16% | Val Loss: 1.3521, Val Acc: 85.90%
# Epoch [9/10] - Train Loss: 1.2848, Train Acc: 85.24% | Val Loss: 1.2912, Val Acc: 84.35%
# Epoch [10/10] - Train Loss: 1.3262, Train Acc: 85.03% | Val Loss: 1.7841, Val Acc: 82.15%
#
# === Training LinearSVM: batch_size=64, lr=0.01, optimizer=RMSprop ===
# Epoch [1/10] - Train Loss: 2.5068, Train Acc: 80.33% | Val Loss: 1.5704, Val Acc: 84.12%
# Epoch [2/10] - Train Loss: 1.5972, Train Acc: 82.76% | Val Loss: 1.3747, Val Acc: 85.53%
# Epoch [3/10] - Train Loss: 1.5209, Train Acc: 83.75% | Val Loss: 1.2991, Val Acc: 87.25%
# Epoch [4/10] - Train Loss: 1.6418, Train Acc: 84.17% | Val Loss: 1.4208, Val Acc: 84.40%
# Epoch [5/10] - Train Loss: 1.5349, Train Acc: 84.70% | Val Loss: 1.3824, Val Acc: 86.78%
# Epoch [6/10] - Train Loss: 1.6035, Train Acc: 84.08% | Val Loss: 1.7761, Val Acc: 83.55%
# Epoch [7/10] - Train Loss: 1.5560, Train Acc: 84.66% | Val Loss: 1.4813, Val Acc: 87.00%
# Epoch [8/10] - Train Loss: 1.5789, Train Acc: 84.71% | Val Loss: 2.1381, Val Acc: 79.30%
# Epoch [9/10] - Train Loss: 1.5689, Train Acc: 84.87% | Val Loss: 1.9816, Val Acc: 82.08%
# Epoch [10/10] - Train Loss: 1.6030, Train Acc: 84.76% | Val Loss: 1.3455, Val Acc: 87.80%
#
# === Training LinearSVM: batch_size=64, lr=0.1, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 1.6376, Train Acc: 80.19% | Val Loss: 1.1713, Val Acc: 83.80%
# Epoch [2/10] - Train Loss: 1.1615, Train Acc: 83.87% | Val Loss: 1.1364, Val Acc: 85.12%
# Epoch [3/10] - Train Loss: 1.1233, Train Acc: 84.38% | Val Loss: 1.3536, Val Acc: 83.00%
# Epoch [4/10] - Train Loss: 1.0604, Train Acc: 84.71% | Val Loss: 1.0738, Val Acc: 85.53%
# Epoch [5/10] - Train Loss: 1.0439, Train Acc: 85.39% | Val Loss: 1.0360, Val Acc: 85.25%
# Epoch [6/10] - Train Loss: 1.0512, Train Acc: 85.13% | Val Loss: 1.1469, Val Acc: 84.72%
# Epoch [7/10] - Train Loss: 1.0263, Train Acc: 85.58% | Val Loss: 1.2158, Val Acc: 83.38%
# Epoch [8/10] - Train Loss: 1.0361, Train Acc: 85.40% | Val Loss: 1.0953, Val Acc: 85.08%
# Epoch [9/10] - Train Loss: 1.0298, Train Acc: 85.36% | Val Loss: 1.2409, Val Acc: 82.58%
# Epoch [10/10] - Train Loss: 1.0378, Train Acc: 85.69% | Val Loss: 1.0892, Val Acc: 85.22%
#
# === Training LinearSVM: batch_size=64, lr=0.1, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 9.2319, Train Acc: 80.36% | Val Loss: 6.7577, Val Acc: 82.62%
# Epoch [2/10] - Train Loss: 6.1131, Train Acc: 83.05% | Val Loss: 6.3702, Val Acc: 81.78%
# Epoch [3/10] - Train Loss: 5.7055, Train Acc: 83.15% | Val Loss: 6.2992, Val Acc: 82.67%
# Epoch [4/10] - Train Loss: 5.4511, Train Acc: 83.59% | Val Loss: 5.1551, Val Acc: 85.25%
# Epoch [5/10] - Train Loss: 5.6503, Train Acc: 83.28% | Val Loss: 6.5252, Val Acc: 82.33%
# Epoch [6/10] - Train Loss: 5.7763, Train Acc: 83.62% | Val Loss: 5.5769, Val Acc: 84.38%
# Epoch [7/10] - Train Loss: 5.0585, Train Acc: 84.23% | Val Loss: 5.5742, Val Acc: 84.30%
# Epoch [8/10] - Train Loss: 5.3490, Train Acc: 83.98% | Val Loss: 5.7184, Val Acc: 85.00%
# Epoch [9/10] - Train Loss: 5.2109, Train Acc: 84.32% | Val Loss: 5.8148, Val Acc: 84.50%
# Epoch [10/10] - Train Loss: 5.2835, Train Acc: 83.91% | Val Loss: 5.7697, Val Acc: 84.17%
#
# === Training LinearSVM: batch_size=64, lr=0.1, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 8.4861, Train Acc: 79.33% | Val Loss: 5.9279, Val Acc: 83.92%
# Epoch [2/10] - Train Loss: 7.8934, Train Acc: 82.16% | Val Loss: 8.7806, Val Acc: 80.75%
# Epoch [3/10] - Train Loss: 8.1146, Train Acc: 82.73% | Val Loss: 8.4334, Val Acc: 83.22%
# Epoch [4/10] - Train Loss: 8.7326, Train Acc: 82.84% | Val Loss: 9.1624, Val Acc: 82.60%
# Epoch [5/10] - Train Loss: 9.3460, Train Acc: 83.14% | Val Loss: 10.3647, Val Acc: 81.03%
# Epoch [6/10] - Train Loss: 9.4284, Train Acc: 83.00% | Val Loss: 9.5857, Val Acc: 82.83%
# Epoch [7/10] - Train Loss: 10.2170, Train Acc: 83.35% | Val Loss: 11.3548, Val Acc: 82.30%
# Epoch [8/10] - Train Loss: 10.0790, Train Acc: 83.43% | Val Loss: 10.1429, Val Acc: 84.67%
# Epoch [9/10] - Train Loss: 9.7201, Train Acc: 84.06% | Val Loss: 9.2567, Val Acc: 85.10%
# Epoch [10/10] - Train Loss: 9.0320, Train Acc: 84.20% | Val Loss: 8.9030, Val Acc: 86.53%
#
# === Training LinearSVM: batch_size=64, lr=0.1, optimizer=RMSprop ===
# Epoch [1/10] - Train Loss: 19.6489, Train Acc: 78.94% | Val Loss: 15.2583, Val Acc: 79.50%
# Epoch [2/10] - Train Loss: 13.5414, Train Acc: 81.59% | Val Loss: 10.1101, Val Acc: 85.20%
# Epoch [3/10] - Train Loss: 13.3112, Train Acc: 81.85% | Val Loss: 12.1790, Val Acc: 84.62%
# Epoch [4/10] - Train Loss: 12.4624, Train Acc: 83.26% | Val Loss: 17.4658, Val Acc: 79.30%
# Epoch [5/10] - Train Loss: 12.7795, Train Acc: 83.21% | Val Loss: 13.1316, Val Acc: 84.70%
# Epoch [6/10] - Train Loss: 12.9640, Train Acc: 83.24% | Val Loss: 9.5841, Val Acc: 87.17%
# Epoch [7/10] - Train Loss: 12.9937, Train Acc: 83.26% | Val Loss: 17.7332, Val Acc: 77.45%
# Epoch [8/10] - Train Loss: 12.5656, Train Acc: 83.72% | Val Loss: 10.8685, Val Acc: 86.05%
# Epoch [9/10] - Train Loss: 12.5754, Train Acc: 83.53% | Val Loss: 11.4564, Val Acc: 85.05%
# Epoch [10/10] - Train Loss: 12.8890, Train Acc: 83.88% | Val Loss: 13.9098, Val Acc: 83.80%
#
# === Training LinearSVM: batch_size=128, lr=0.001, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 2.0378, Train Acc: 69.75% | Val Loss: 1.0742, Val Acc: 81.35%
# Epoch [2/10] - Train Loss: 0.9533, Train Acc: 82.99% | Val Loss: 0.8395, Val Acc: 84.75%
# Epoch [3/10] - Train Loss: 0.8303, Train Acc: 84.94% | Val Loss: 0.7735, Val Acc: 85.12%
# Epoch [4/10] - Train Loss: 0.7542, Train Acc: 85.74% | Val Loss: 0.7370, Val Acc: 85.72%
# Epoch [5/10] - Train Loss: 0.7182, Train Acc: 86.45% | Val Loss: 0.6860, Val Acc: 86.92%
# Epoch [6/10] - Train Loss: 0.6939, Train Acc: 86.69% | Val Loss: 0.6786, Val Acc: 86.38%
# Epoch [7/10] - Train Loss: 0.6648, Train Acc: 87.17% | Val Loss: 0.6462, Val Acc: 86.55%
# Epoch [8/10] - Train Loss: 0.6473, Train Acc: 87.41% | Val Loss: 0.6150, Val Acc: 87.67%
# Epoch [9/10] - Train Loss: 0.6454, Train Acc: 87.12% | Val Loss: 0.6157, Val Acc: 87.55%
# Epoch [10/10] - Train Loss: 0.6199, Train Acc: 87.65% | Val Loss: 0.5966, Val Acc: 87.67%
#
# === Training LinearSVM: batch_size=128, lr=0.001, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 1.1203, Train Acc: 80.74% | Val Loss: 0.6021, Val Acc: 86.60%
# Epoch [2/10] - Train Loss: 0.6203, Train Acc: 87.12% | Val Loss: 0.5675, Val Acc: 87.95%
# Epoch [3/10] - Train Loss: 0.5808, Train Acc: 87.64% | Val Loss: 0.5520, Val Acc: 87.78%
# Epoch [4/10] - Train Loss: 0.5687, Train Acc: 88.09% | Val Loss: 0.5670, Val Acc: 87.72%
# Epoch [5/10] - Train Loss: 0.5381, Train Acc: 88.54% | Val Loss: 0.5389, Val Acc: 88.50%
# Epoch [6/10] - Train Loss: 0.5216, Train Acc: 88.76% | Val Loss: 0.5570, Val Acc: 88.17%
# Epoch [7/10] - Train Loss: 0.5262, Train Acc: 89.04% | Val Loss: 0.5376, Val Acc: 88.62%
# Epoch [8/10] - Train Loss: 0.5253, Train Acc: 88.81% | Val Loss: 0.5202, Val Acc: 88.78%
# Epoch [9/10] - Train Loss: 0.5003, Train Acc: 89.28% | Val Loss: 0.5269, Val Acc: 88.60%
# Epoch [10/10] - Train Loss: 0.5084, Train Acc: 89.16% | Val Loss: 0.5184, Val Acc: 88.08%
#
# === Training LinearSVM: batch_size=128, lr=0.001, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 1.4067, Train Acc: 76.82% | Val Loss: 0.7157, Val Acc: 85.75%
# Epoch [2/10] - Train Loss: 0.6699, Train Acc: 86.39% | Val Loss: 0.6102, Val Acc: 87.75%
# Epoch [3/10] - Train Loss: 0.5920, Train Acc: 87.51% | Val Loss: 0.5536, Val Acc: 88.25%
# Epoch [4/10] - Train Loss: 0.5620, Train Acc: 88.24% | Val Loss: 0.5417, Val Acc: 88.17%
# Epoch [5/10] - Train Loss: 0.5412, Train Acc: 88.74% | Val Loss: 0.5351, Val Acc: 88.90%
# Epoch [6/10] - Train Loss: 0.5285, Train Acc: 88.67% | Val Loss: 0.5265, Val Acc: 87.88%
# Epoch [7/10] - Train Loss: 0.5152, Train Acc: 89.00% | Val Loss: 0.4980, Val Acc: 88.53%
# Epoch [8/10] - Train Loss: 0.4954, Train Acc: 89.19% | Val Loss: 0.5074, Val Acc: 88.85%
# Epoch [9/10] - Train Loss: 0.5055, Train Acc: 89.30% | Val Loss: 0.5265, Val Acc: 88.58%
# Epoch [10/10] - Train Loss: 0.4927, Train Acc: 89.50% | Val Loss: 0.5275, Val Acc: 88.25%
#
# === Training LinearSVM: batch_size=128, lr=0.001, optimizer=RMSprop ===
# Epoch [1/10] - Train Loss: 1.0007, Train Acc: 81.51% | Val Loss: 0.6667, Val Acc: 86.53%
# Epoch [2/10] - Train Loss: 0.6133, Train Acc: 87.13% | Val Loss: 0.6205, Val Acc: 86.10%
# Epoch [3/10] - Train Loss: 0.5598, Train Acc: 87.76% | Val Loss: 0.5376, Val Acc: 88.22%
# Epoch [4/10] - Train Loss: 0.5503, Train Acc: 88.37% | Val Loss: 0.5707, Val Acc: 87.25%
# Epoch [5/10] - Train Loss: 0.5387, Train Acc: 88.58% | Val Loss: 0.5270, Val Acc: 88.35%
# Epoch [6/10] - Train Loss: 0.5298, Train Acc: 88.58% | Val Loss: 0.5347, Val Acc: 88.08%
# Epoch [7/10] - Train Loss: 0.5140, Train Acc: 88.91% | Val Loss: 0.5190, Val Acc: 88.20%
# Epoch [8/10] - Train Loss: 0.5153, Train Acc: 88.88% | Val Loss: 0.5317, Val Acc: 88.17%
# Epoch [9/10] - Train Loss: 0.5091, Train Acc: 88.81% | Val Loss: 0.5537, Val Acc: 87.78%
# Epoch [10/10] - Train Loss: 0.5140, Train Acc: 88.87% | Val Loss: 0.5164, Val Acc: 88.30%
#
# === Training LinearSVM: batch_size=128, lr=0.01, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 0.9776, Train Acc: 82.06% | Val Loss: 0.6720, Val Acc: 85.15%
# Epoch [2/10] - Train Loss: 0.6350, Train Acc: 87.13% | Val Loss: 0.6030, Val Acc: 87.15%
# Epoch [3/10] - Train Loss: 0.5813, Train Acc: 87.69% | Val Loss: 0.5617, Val Acc: 87.55%
# Epoch [4/10] - Train Loss: 0.5519, Train Acc: 88.14% | Val Loss: 0.5306, Val Acc: 88.22%
# Epoch [5/10] - Train Loss: 0.5398, Train Acc: 88.39% | Val Loss: 0.5325, Val Acc: 88.30%
# Epoch [6/10] - Train Loss: 0.5396, Train Acc: 88.79% | Val Loss: 0.5638, Val Acc: 87.45%
# Epoch [7/10] - Train Loss: 0.5343, Train Acc: 88.64% | Val Loss: 0.5268, Val Acc: 88.33%
# Epoch [8/10] - Train Loss: 0.5081, Train Acc: 89.08% | Val Loss: 0.5135, Val Acc: 88.53%
# Epoch [9/10] - Train Loss: 0.5154, Train Acc: 89.16% | Val Loss: 0.4977, Val Acc: 89.08%
# Epoch [10/10] - Train Loss: 0.4972, Train Acc: 89.28% | Val Loss: 0.5070, Val Acc: 88.50%
#
# === Training LinearSVM: batch_size=128, lr=0.01, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 1.3318, Train Acc: 82.26% | Val Loss: 0.9044, Val Acc: 84.47%
# Epoch [2/10] - Train Loss: 0.8236, Train Acc: 86.19% | Val Loss: 0.7171, Val Acc: 86.85%
# Epoch [3/10] - Train Loss: 0.7504, Train Acc: 86.66% | Val Loss: 0.7431, Val Acc: 85.05%
# Epoch [4/10] - Train Loss: 0.7081, Train Acc: 86.59% | Val Loss: 0.7301, Val Acc: 86.15%
# Epoch [5/10] - Train Loss: 0.7068, Train Acc: 86.40% | Val Loss: 0.7069, Val Acc: 86.58%
# Epoch [6/10] - Train Loss: 0.6764, Train Acc: 87.19% | Val Loss: 0.6697, Val Acc: 87.60%
# Epoch [7/10] - Train Loss: 0.6614, Train Acc: 87.02% | Val Loss: 0.7210, Val Acc: 86.45%
# Epoch [8/10] - Train Loss: 0.6656, Train Acc: 87.23% | Val Loss: 0.6716, Val Acc: 87.47%
# Epoch [9/10] - Train Loss: 0.6605, Train Acc: 87.16% | Val Loss: 0.6777, Val Acc: 87.40%
# Epoch [10/10] - Train Loss: 0.6518, Train Acc: 87.24% | Val Loss: 0.6993, Val Acc: 86.97%
#
# === Training LinearSVM: batch_size=128, lr=0.01, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 1.2347, Train Acc: 81.86% | Val Loss: 0.8706, Val Acc: 83.85%
# Epoch [2/10] - Train Loss: 0.8291, Train Acc: 85.12% | Val Loss: 0.9099, Val Acc: 85.38%
# Epoch [3/10] - Train Loss: 0.9060, Train Acc: 85.22% | Val Loss: 0.9236, Val Acc: 84.83%
# Epoch [4/10] - Train Loss: 0.9097, Train Acc: 85.59% | Val Loss: 1.0696, Val Acc: 83.72%
# Epoch [5/10] - Train Loss: 0.8950, Train Acc: 85.40% | Val Loss: 0.8817, Val Acc: 85.78%
# Epoch [6/10] - Train Loss: 1.0194, Train Acc: 84.97% | Val Loss: 0.8978, Val Acc: 85.97%
# Epoch [7/10] - Train Loss: 0.8860, Train Acc: 86.09% | Val Loss: 0.9092, Val Acc: 85.83%
# Epoch [8/10] - Train Loss: 0.9237, Train Acc: 86.12% | Val Loss: 1.0703, Val Acc: 84.00%
# Epoch [9/10] - Train Loss: 0.9679, Train Acc: 85.72% | Val Loss: 1.0313, Val Acc: 85.45%
# Epoch [10/10] - Train Loss: 0.9187, Train Acc: 86.19% | Val Loss: 0.9386, Val Acc: 86.47%
#
# === Training LinearSVM: batch_size=128, lr=0.01, optimizer=RMSprop ===
# Epoch [1/10] - Train Loss: 2.5599, Train Acc: 79.60% | Val Loss: 1.3299, Val Acc: 83.42%
# Epoch [2/10] - Train Loss: 1.4511, Train Acc: 83.17% | Val Loss: 1.4741, Val Acc: 84.20%
# Epoch [3/10] - Train Loss: 1.3798, Train Acc: 83.47% | Val Loss: 1.4330, Val Acc: 82.62%
# Epoch [4/10] - Train Loss: 1.3598, Train Acc: 84.10% | Val Loss: 1.2782, Val Acc: 85.20%
# Epoch [5/10] - Train Loss: 1.3878, Train Acc: 83.83% | Val Loss: 1.2006, Val Acc: 84.83%
# Epoch [6/10] - Train Loss: 1.2949, Train Acc: 84.41% | Val Loss: 1.6750, Val Acc: 80.85%
# Epoch [7/10] - Train Loss: 1.3039, Train Acc: 84.31% | Val Loss: 1.2923, Val Acc: 85.62%
# Epoch [8/10] - Train Loss: 1.3072, Train Acc: 85.06% | Val Loss: 1.1295, Val Acc: 85.92%
# Epoch [9/10] - Train Loss: 1.3164, Train Acc: 84.50% | Val Loss: 1.2942, Val Acc: 85.85%
# Epoch [10/10] - Train Loss: 1.3517, Train Acc: 84.96% | Val Loss: 1.1735, Val Acc: 86.58%
#
# === Training LinearSVM: batch_size=128, lr=0.1, optimizer=SGD ===
# Epoch [1/10] - Train Loss: 1.5114, Train Acc: 79.73% | Val Loss: 0.8484, Val Acc: 85.42%
# Epoch [2/10] - Train Loss: 0.9655, Train Acc: 84.17% | Val Loss: 1.0744, Val Acc: 81.97%
# Epoch [3/10] - Train Loss: 1.0043, Train Acc: 83.93% | Val Loss: 0.8197, Val Acc: 85.05%
# Epoch [4/10] - Train Loss: 0.8756, Train Acc: 85.17% | Val Loss: 0.7713, Val Acc: 86.95%
# Epoch [5/10] - Train Loss: 0.8727, Train Acc: 85.22% | Val Loss: 0.7753, Val Acc: 86.83%
# Epoch [6/10] - Train Loss: 0.9095, Train Acc: 85.18% | Val Loss: 0.8511, Val Acc: 86.35%
# Epoch [7/10] - Train Loss: 0.8110, Train Acc: 86.16% | Val Loss: 0.7333, Val Acc: 87.40%
# Epoch [8/10] - Train Loss: 0.8378, Train Acc: 85.73% | Val Loss: 0.8548, Val Acc: 85.15%
# Epoch [9/10] - Train Loss: 0.8686, Train Acc: 85.37% | Val Loss: 0.7993, Val Acc: 86.20%
# Epoch [10/10] - Train Loss: 0.7926, Train Acc: 86.11% | Val Loss: 0.7452, Val Acc: 86.80%
#
# === Training LinearSVM: batch_size=128, lr=0.1, optimizer=SGD_momentum ===
# Epoch [1/10] - Train Loss: 6.5487, Train Acc: 81.73% | Val Loss: 4.8227, Val Acc: 81.67%
# Epoch [2/10] - Train Loss: 3.9469, Train Acc: 84.03% | Val Loss: 3.4707, Val Acc: 82.88%
# Epoch [3/10] - Train Loss: 3.2063, Train Acc: 84.06% | Val Loss: 3.5077, Val Acc: 83.65%
# Epoch [4/10] - Train Loss: 3.3212, Train Acc: 83.57% | Val Loss: 2.9559, Val Acc: 84.53%
# Epoch [5/10] - Train Loss: 2.9089, Train Acc: 84.26% | Val Loss: 3.0036, Val Acc: 84.05%
# Epoch [6/10] - Train Loss: 3.0214, Train Acc: 84.12% | Val Loss: 3.4373, Val Acc: 81.92%
# Epoch [7/10] - Train Loss: 2.8752, Train Acc: 84.39% | Val Loss: 2.7742, Val Acc: 84.83%
# Epoch [8/10] - Train Loss: 2.9677, Train Acc: 83.88% | Val Loss: 3.4578, Val Acc: 84.30%
# Epoch [9/10] - Train Loss: 2.9970, Train Acc: 84.58% | Val Loss: 3.0136, Val Acc: 85.22%
# Epoch [10/10] - Train Loss: 2.8987, Train Acc: 84.46% | Val Loss: 2.7457, Val Acc: 85.10%
#
# === Training LinearSVM: batch_size=128, lr=0.1, optimizer=Adam ===
# Epoch [1/10] - Train Loss: 7.6469, Train Acc: 79.54% | Val Loss: 5.1362, Val Acc: 83.00%

# %% [markdown]
# **Implement** a Softmax classifier in the following cell. Your implementation should be a python class that inherits from `torch.nn.Module`.

# %% [markdown]
# ***Implement*** using any PyTorch defined optimizer, train your Softmax classifier on the training dataset and validate on the validation dataset, as you did before.
#
# ***Note:*** You should keep track of the performance of the optimizers, batch sizes, and learning rates. You should justify the choice of your hyperparameters in the report at the end of this section. You will be asked to quantify and visualize the differences between these hyperparameters.
#
# You will want to try different optimizers, learning rates, and batch sizes. You should use `Torch.DataLoader` to simplify the data loading. Make sure to use the correct loss function. You may use predefined loss functions available in `Torch.nn`.
#
# Same as before, to train a single model, you will need to:
#
# - Iterate through the data in batches using your training or validation dataloader
# - Perform the forward pass
# - Compute the loss
# - Perform the backward pass
# - Take an optimizer step
# - Repeat the process till network converges or some other criterion
# - Every n iterations, go through the validation set and calculate the loss and accuracy of the validation set to check your training performance

# %% [markdown]
# ***Implement*** visualizations in the following cell to show performance differences of the different hyperparameters.
#
# ***Include*** visualizations for the effect of different batch sizes, learning rates, and optimizers. You are free to choose any method of visualization as long as it is able to succintly convey your justifications.

# %% [markdown]
# ### Convolutional Neural Networks

# %% [markdown]
# ***Implement*** the following cell to implement a convolutional neural network. Similar to before, your implementation should be a Python class that inherits from `torch.nn.Module`.
#
# Your model can use any of the building blocks defined in `torch.nn` including but not limited to:
#
# - Conv2D
# - Linear
# - Activation layers:
#   - ReLU
#   - Tanh
#   - Sigmoid
#   - Softmax
# - Normalization layers:
#   - BatchNorm
#   - LayerNorm
#   - GroupNorm
# - Pooling layers:
#   - MaxPool
#   - AvgPool
# - Dropout
#
# Make sure to chose the correct dimensional versions of the layers, i.e for images use MaxPool2d and vectors use MaxPool1d

# %% [markdown]
# Example LeNet implementation:
#
# ```python
# class LeNet(nn.Module):
#
#     def __init__(self, num_classes=10):
#         super(LeNet, self).__init__()
#
#         # num_classes number of output classes
#         self.num_classes = num_classes
#         # 1 input image channel,
#         # 6 output channels
#         # 5x5 square convolution kernel
#         self.conv1 = nn.Conv2d(1, 6, 5)
#         # ReLU activation function
#         self.act1 = nn.ReLU()
#         # Max pooling with 2x2 square kernel
#         self.pool1 = nn.MaxPool2d(2)
#
#         # Second convolution with 6 input image channels
#         self.conv2 = nn.Conv2d(6, 16, 5)
#         self.act2 = nn.ReLU()
#         self.pool2 = nn.MaxPool2d(2)
#
#         # 3 Layer fully connected layer
#         self.fc1 = nn.Linear(16 * 4 * 4, 120)
#         self.act3 = nn.ReLU()
#         self.fc2 = nn.Linear(120, 84)
#         self.act4 = nn.ReLU()
#         self.fc3 = nn.Linear(84, num_classes)
#
#     def forward(self, x):
#
#         # First Convolution -> Activation -> Max Pooling
#         x = self.conv1(x)
#         x = self.act1(x)
#         x = self.pool1(x)
#
#         # Second Convolution -> Activation -> Max Pooling
#         x = self.conv2(x)
#         x = self.act2(x)
#         x = self.pool2(x)
#
#         # flatten all dimensions except the batch dimension
#         x = torch.flatten(x, 1)
#
#         # Three layer MLP with ReLU activations
#         x = self.act3(self.fc1(x))
#         x = self.act4(self.fc2(x))
#         x = self.fc3(x)
#
#         return x
#
# ```

# %% [markdown]
# In the following cells, perform experiments using the CNN you defined. You may need to reshape your data in order to 2D convolutions.
#
# Your objective is to find the best architecture that minimizes the error but using as few a parameters and FLOPS as possible.
#
# ***Performance matters!*** The model with the best combination of high accuracy, parameter, and compute efficiency will get extra credit (15 pts).

# %% [markdown]
# **Implement** the following cell to compute and compare the test set performance (accuracy) of the linear classifiers and CNN.

# %% [markdown]
# In the following cells ***write*** a short justification on how you came up with your final model and architecture. You may include details like:
#
# - Which optimizer did you use? Why did you use that?
# - What about the other hyperparameters?
# - Did you base your model on an existing architecture?
# - What changes did you make to improve accuracy?
# - What changes did you make to improvde performance?
#
# ***Include*** visualizations for the effect of different batch sizes, learning rates, and optimizers. You are free to choose any method of visualization as long as it is able to succintly convey your justifications.

# %% [markdown]
# ## Part 3: Real World Data (40 pts)

# %% [markdown]
# While test set accuracy is meant to approximate the perfomance in real world data, biases in data collection and processing often result in inaccurate performance estimates. In this section, you will be using the previously defined models to re-train on the data the class has collected.
#
# In user systems, noisy inputs are often likely. To make your model robust to faulty input, you will need to add an additional class to your model which corresponds to the label 10. This label is reserved for inputs that are **not** digits.

# %% [markdown]
# ***Implement*** the following cells to load and convert the new dataset and combine the new dataset with old dataset.
#
# Make sure you have downloaded the `MNIST580E_training.csv` and `MNIST580E_test.csv` files from the shared drive and uplodaded it to your GDrive. You will be combining our collected data with the MNIST dataset available with Colab.
#
# You will need to:
#
#
# - Mount your GDrive
# - Load the `MNIST580E_training.csv` and `MNIST580E_test.csv` files
# - Parse the files and create train and test datasets as you did previously
#   - Make sure to normalize the data and add data augmentation. You are free to use any augmentation you'd like.
# - Combine the new datasets with the dataset available on Colab.
#   - You can use the `ConcatDataset` or `ChainDataset`.
# - Visualize the newly created data. This should serve as a sanity check for your newly written data pipeline.
#
# **Data Augmentation:**
#
# The collected data will have more variability compared to the original dataset.
# So you should make heavy use of data augmentation on the collected dataset. You can use augmentations such as as:
#
# - Rotation
# - Resize
# - Blur
# - Perspective shift
#
# **Another hint:** Since we are adding an additional class type (not a digit), our dataset will be imbalanced. There will be fewer samples with that label compared to other labels. You may want to "double count" (i.e duplicate) the not-a-digit samples in your collected dataset.

# %% [markdown]
# **Implement** the following cell to use your previously trained CNN as a feature extractor. This is an example of [transfer learning](https://en.wikipedia.org/wiki/Transfer_learning).
#
# You will need to:
# - Freeze the layers of convolutional model you trained
# - Change the final linear layer have an additional output for the additional class.
#
# Here's an example of taking the previously defined LeNet and updating the final layer to have 11 classes instead of 10. This also freezes the other weights in the LeNet.
#
# ```python
# # model_conv is a trained LeNet example from above
#
# # Freeze the weights of the model
# # The gradients will not be calculated and the optimizer will not
# # update the weights
# for param in model_conv.parameters():
#     param.requires_grad = False
#
# # Parameters of newly constructed modules have requires_grad=True by default
# num_ftrs = model_conv.fc3.in_features
# model_conv.fc3 = nn.Linear(num_ftrs, 11)
#
# model_conv = model_conv.to(device)
#
# criterion = nn.CrossEntropyLoss()
#
# # Only parameters of final layer are being optimized not the other weights
# optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001)
# ```

# %% [markdown]
# **Implement** the following cell to train the final layer of the convolution. Also calculate the test set performance on this fine-tuned model.

# %% [markdown]
# ***Implement*** the following cell to retrain the linear classifiers (LinearSVM and Softmax). Note that you have an extra class as your model should also detect "not a digit".

# %% [markdown]
# ***Implement*** the following cell to retrain your previously defined CNN model.

# %% [markdown]
# **Implement** a visualization of the [confusion matrix](https://en.wikipedia.org/wiki/Confusion_matrix) on the **new** combined test set with the predictions from your LinearSVM, Softmax, and CNN. You should use a single `Matplotlib` figure with multiple subplots on a single row.
#
# [See here for examples on using plt.subplots.](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html)

# %% [markdown]
# In the following cells, write a short report about the performance of your models. You should include the effects of new data, data augmentation, and different architectures. You should also include visualizations as you did before.
